# %%
# !pip install mysql-connector

# %%
import mysql.connector  as sql

# %%
cnx = sql.connect(user='root', password='sabihinmo123', database='interpol')

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
pip install pymysql
# Out:
# ...
#                                               0.0/44.8 kB ? eta -:--:--
#      ---------------------------------------- 44.8/44.8 kB 2.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %sql mysql+pymysql://root:sabihinmo123@localhost/interpol

# %%
# %%sql
#
# SELECT *
# FROM population;
# Out:
#  * mysql+pymysql://root:***@localhost/interpol
# 194 rows affected.
# [(1, "People's Republic of China", 1412360000, 721140373, 691219627, '151.27 per km²'),
#  (2, 'India', 1393409033, 726503429, 681060412, '480.5 per km²'),
#  (3, 'United States of America', 331893745, 164413285, 167480460, '37.17 per km²'),
#  (4, 'Indonesia', 276361788, 137852478, 135900714, '147.82 per km²'),
#  (5, 'Pakistan', 225199929, 116815852, 114586264, '311.96 per km²'),
#  (6, 'Brazil', 213993441, 105291292, 109034931, '25.89 per km²'),
#  (7, 'Nigeria', 211400704, 107827012, 105574310, '245.73 per km²'),
#  (8, 'Bangladesh', 166303494, 83998088, 85358163, '1,328.68 per km²'),
#  (9, 'Russia', 143446060, 66624709, 76824577, '8.82 per km²'),
#  (10, 'Mexico', 130262220, 61856137, 64849001, '66.08 per km²'),
#  (11, 'Japan', 125681593, 61087180, 64594414, '338.26 per km²'),
#  (12, 'Ethiopia', 117876226, 60443404, 59839622, '112.11 per km²'),
# ...
