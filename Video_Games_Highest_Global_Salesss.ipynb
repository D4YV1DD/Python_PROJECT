# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import seaborn as sns

# %%
df = pd.read_csv('vgsales.csv')

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# ### Best Genre Game Analysis ###

# %%
year_column = df['Genre'].drop_duplicates()
print(year_column)
# Out:
# 0            Sports
# 1          Platform
# 2            Racing
# 4      Role-Playing
# 5            Puzzle
# 7              Misc
# 9           Shooter
# 10       Simulation
# 16           Action
# 39         Fighting
# 50        Adventure
# 165        Strategy
# Name: Genre, dtype: object

# %%
df['Year'] = df['Year'].astype(str)
df['new_year'] = df['Year'].str[0:4]
print(df.head())
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales new_year
# 0     41.49     29.02      3.77         8.46         82.74     2006
# 1     29.08      3.58      6.81         0.77         40.24     1985
# 2     15.85     12.88      3.79         3.31         35.82     2008
# 3     15.75     11.01      3.28         2.96         33.00     2009
# 4     11.27      8.89     10.22         1.00         31.37     1996

# %%
highest_global_sales = df.sort_values('Global_Sales', ascending=False)
result = highest_global_sales[['new_year','Name' ,'Global_Sales']]
top30 = result.head(100)
print(top30.to_string(index=False))
# Out:
# new_year                                         Name  Global_Sales
#     2006                                   Wii Sports         82.74
#     1985                            Super Mario Bros.         40.24
#     2008                               Mario Kart Wii         35.82
#     2009                            Wii Sports Resort         33.00
#     1996                     Pokemon Red/Pokemon Blue         31.37
#     1989                                       Tetris         30.26
#     2006                        New Super Mario Bros.         30.01
#     2006                                     Wii Play         29.02
#     2009                    New Super Mario Bros. Wii         28.62
#     1984                                    Duck Hunt         28.31
#     2005                                   Nintendogs         24.76
#     2005                                Mario Kart DS         23.42
#     1999                  Pokemon Gold/Pokemon Silver         23.10
#     2007                                      Wii Fit         22.72
#     2009                                 Wii Fit Plus         22.00
#     2010                           Kinect Adventures!         21.82
#     2013                           Grand Theft Auto V         21.40
#     2004                Grand Theft Auto: San Andreas         20.81
#     1990                            Super Mario World         20.61
#     2005 Brain Age: Train Your Brain in Minutes a Day         20.22
#     2006                Pokemon Diamond/Pokemon Pearl         18.36
#     1989                             Super Mario Land         18.14
#     1988                          Super Mario Bros. 3         17.28
#     2013                           Grand Theft Auto V         16.38
#     2002                  Grand Theft Auto: Vice City         16.15
#     2002                Pokemon Ruby/Pokemon Sapphire         15.85
#     2010                  Pokemon Black/Pokemon White         15.32
#     2005  Brain Age 2: More Training in Minutes a Day         15.30
#     2001                       Gran Turismo 3: A-Spec         14.98
#     2011               Call of Duty: Modern Warfare 3         14.76
#     1998      Pokémon Yellow: Special Pikachu Edition         14.64
#     2010                      Call of Duty: Black Ops         14.64
#     2013                          Pokemon X/Pokemon Y         14.35
#     2015                    Call of Duty: Black Ops 3         14.24
#     2012                   Call of Duty: Black Ops II         14.03
#     2012                   Call of Duty: Black Ops II         13.73
#     2009               Call of Duty: Modern Warfare 2         13.51
#     2011               Call of Duty: Modern Warfare 3         13.46
#     2001                         Grand Theft Auto III         13.10
#     2008                      Super Smash Bros. Brawl         13.04
#     2010                      Call of Duty: Black Ops         12.73
#     2005                  Animal Crossing: Wild World         12.27
#     2011                                 Mario Kart 7         12.21
#     2007                                       Halo 3         12.14
#     2014                           Grand Theft Auto V         11.98
#     2009         Pokemon HeartGold/Pokemon SoulSilver         11.90
#     1996                               Super Mario 64         11.89
#     2004                               Gran Turismo 4         11.66
#     2007                           Super Mario Galaxy         11.52
#     2014    Pokemon Omega Ruby/Pokemon Alpha Sapphire         11.33
#     1992           Super Mario Land 2: 6 Golden Coins         11.18
#     2008                          Grand Theft Auto IV         11.02
#     1997                                 Gran Turismo         10.95
#     2011                          Super Mario 3D Land         10.79
#     2010                               Gran Turismo 5         10.77
#     2009               Call of Duty: Modern Warfare 2         10.69
#     2008                          Grand Theft Auto IV         10.57
#     1993                        Super Mario All-Stars         10.55
#     2004            Pokemon FireRed/Pokemon LeafGreen         10.49
#     2004                               Super Mario 64         10.42
#     2011                                 Just Dance 3         10.26
#     2013                         Call of Duty: Ghosts         10.21
#     2010                                  Halo: Reach          9.88
#     1996                                Mario Kart 64          9.87
#     2012                      New Super Mario Bros. 2          9.82
#     2012                                       Halo 4          9.76
#     1997                            Final Fantasy VII          9.72
#     2013                         Call of Duty: Ghosts          9.59
#     2010                                 Just Dance 2          9.52
#     1999                               Gran Turismo 2          9.49
#     2007               Call of Duty 4: Modern Warfare          9.32
#     1994                          Donkey Kong Country          9.30
#     2013                                    Minecraft          9.20
#     2012                    Animal Crossing: New Leaf          9.09
#     2007                               Mario Party DS          9.02
#     2011                  The Elder Scrolls V: Skyrim          8.84
#     1992                             Super Mario Kart          8.76
#     2015                                      FIFA 16          8.49
#     2010                                    Wii Party          8.49
#     2004                                       Halo 2          8.49
#     2007                                Mario Party 8          8.42
#     2012              Pokemon Black 2/Pokemon White 2          8.33
#     2012                               FIFA Soccer 13          8.24
#     2009                                   The Sims 3          8.11
#     1997                                GoldenEye 007          8.09
#     2007           Mario & Sonic at the Olympic Games          8.06
#     2001                              Final Fantasy X          8.05
#     1999                           Final Fantasy VIII          7.86
#     2008                     Pokémon Platinum Version          7.84
#     1982                                      Pac-Man          7.81
#     2005       Grand Theft Auto: Liberty City Stories          7.72
#     2010                         Super Mario Galaxy 2          7.69
#     2015                 Star Wars Battlefront (2015)          7.67
#     2014               Call of Duty: Advanced Warfare          7.60
#     1998         The Legend of Zelda: Ocarina of Time          7.60
#     1997       Crash Bandicoot 2: Cortex Strikes Back          7.58
#     1988                          Super Mario Bros. 2          7.46
#     2014          Super Smash Bros. for Wii U and 3DS          7.45
#     2008                   Call of Duty: World at War          7.37
#     2011                                Battlefield 3          7.34

# %%
plt.figure(figsize=(12, 8))
sns.set(style="whitegrid")
sns.lineplot(data=top30, x='new_year', y='Global_Sales', marker='o', color='skyblue')
plt.xlabel('Year')
plt.ylabel('Global Sales (in millions)')
plt.title('Global Sales Top Trend Games Over the Years', fontsize=16, fontweight='bold')
plt.xticks(rotation=45)
plt.show()

# %%
highest_global_sales = df.sort_values('Global_Sales', ascending=False)
result = highest_global_sales[['new_year','Name' ,'Global_Sales']]
top30 = result.head(10)
print(top30.to_string(index=False))
# Out:
# new_year                      Name  Global_Sales
#     2006                Wii Sports         82.74
#     1985         Super Mario Bros.         40.24
#     2008            Mario Kart Wii         35.82
#     2009         Wii Sports Resort         33.00
#     1996  Pokemon Red/Pokemon Blue         31.37
#     1989                    Tetris         30.26
#     2006     New Super Mario Bros.         30.01
#     2006                  Wii Play         29.02
#     2009 New Super Mario Bros. Wii         28.62
#     1984                 Duck Hunt         28.31

# %%
heatmap_data = top30.pivot(index='Name', columns='new_year', values='Global_Sales')
plt.figure(figsize=(12, 8))
sns.set(style="whitegrid")
sns.heatmap(heatmap_data, cmap='YlGnBu', annot=True, fmt=".2f", linewidths=0.5, cbar=True)
plt.xlabel('Year')
plt.ylabel('Game Name')
plt.title('Top 10 Most highest Global Sales Video Games')

plt.show()

# %%
total_publisher_sales = df.groupby('Publisher')['Global_Sales'].sum()
total_publisher_sales_sorted = total_publisher_sales.sort_values(ascending=False)
top30 = total_publisher_sales_sorted.head(30)
print(top30.to_string(index=False))
# Out:
# Publisher
# 1786.56
# 1110.32
#  727.46
#  607.50
#  474.72
#  399.54
#  340.77
#  283.64
#  272.99
#  254.09
#  245.79
#  200.89
#  157.22
#  153.89
#  145.18
#  119.96
#   98.98
#   87.34
#   82.14
#   69.85
#   64.14
#   58.21
#   57.65
#   55.91
#   53.55
#   47.87
#   43.87
#   34.66
#   33.74
#   25.67

# %%
plt.figure(figsize=(14, 8))
sns.barplot(x=top30.values, y=top30.index, palette='plasma')
plt.xlabel('Total Global Sales (in millions)')
plt.ylabel('Publisher')
plt.title('Top 30 Highest Global Sales  Game Publisher ')

plt.show()

# %%
total_publisher_sales = df.groupby('Publisher')['Global_Sales'].sum()
total_publisher_sales_sorted = total_publisher_sales.sort_values(ascending=False)
top30 = total_publisher_sales_sorted.head(30)
print(top30.to_string(index=False))
# Out:
# Publisher
# 1786.56
# 1110.32
#  727.46
#  607.50
#  474.72
#  399.54
#  340.77
#  283.64
#  272.99
#  254.09
#  245.79
#  200.89
#  157.22
#  153.89
#  145.18
#  119.96
#   98.98
#   87.34
#   82.14
#   69.85
#   64.14
#   58.21
#   57.65
#   55.91
#   53.55
#   47.87
#   43.87
#   34.66
#   33.74
#   25.67

# %%
game_publisher = df['Publisher'].drop_duplicates()
print(game_publisher.head(50))
# Out:
# 0                                    Nintendo
# 15                     Microsoft Game Studios
# 16                       Take-Two Interactive
# 28                Sony Computer Entertainment
# 29                                 Activision
# 60                                    Ubisoft
# 75                         Bethesda Softworks
# 77                            Electronic Arts
# 85                                       Sega
# 87                                 SquareSoft
# 89                                      Atari
# 117                                 505 Games
# 136                                    Capcom
# 138                            GT Interactive
# 142              Konami Digital Entertainment
# 146        Sony Computer Entertainment Europe
# 147                               Square Enix
# 150                                 LucasArts
# 151                        Virgin Interactive
# 159    Warner Bros. Interactive Entertainment
# 167                     Universal Interactive
# 178                         Eidos Interactive
# 195                                 RedOctane
# 224                             Vivendi Games
# 242                          Enix Corporation
# 264                        Namco Bandai Games
# 276                                    Palcom
# 278                        Hasbro Interactive
# 358                                       THQ
# 359                           Fox Interactive
# 397                     Acclaim Entertainment
# 427                                 MTV Games
# 434                Disney Interactive Studios
# 470                                       NaN
# 501                     Majesco Entertainment
# 504                               Codemasters
# 521                                   Red Orb
# 561                                   Level 5
# 564                       Arena Entertainment
# 610                              Midway Games
# 646                                       JVC
# 655                               Deep Silver
# 689                               989 Studios
# 691                                    NCSoft
# 715                               UEP Systems
# 734                              Parker Bros.
# 765                                     Maxis
# 766                                    Imagic
# 783                                Tecmo Koei
# 789                            Valve Software
# Name: Publisher, dtype: object

# %%
sports = df[df['Genre'] == 'Platform']
sales = sports.sort_values('Global_Sales',ascending=False)
result = sales[['Name','Global_Sales']]
top15 = result.head(20)
print(top15.to_string(index=False))
# Out:
#                
# Grand Theft Auto: Liberty City Stories          7.72
#   The Legend of Zelda: Ocarina of Time          7.60
# The Legend of Zelda: Twilight Princess          7.31
#         Uncharted 3: Drake's Deception          6.83
#             Uncharted 2: Among Thieves          6.73
#                    Red Dead Redemption          6.60
#                    The Legend of Zelda          6.51
#                   Assassin's Creed III          6.50
#                    Red Dead Redemption          6.34
#                                 Driver          6.27

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=top15, x='Global_Sales', y='Name', palette='viridis')
plt.xlabel('Global Sales (in millions)')
plt.ylabel('Game Name')
plt.title('Top 20 Highest Global Sales in Action Games')

plt.show()

# %%
sports = df[df['Genre'] == 'Fighting']
sales = sports.sort_values('Global_Sales',ascending=False)
result = sales[['Name','Global_Sales']]
top15 = result.head(20)
print(top15.to_string(index=False))
# Out:
#                                 Name  Global_Sales
#              Super Smash Bros. Brawl         13.04
#  Super Smash Bros. for Wii U and 3DS          7.45
#                             Tekken 3          7.16
#              Super Smash Bros. Melee          7.07
# Street Fighter II: The World Warrior          6.30
#                             Tekken 2          5.74
#                    Super Smash Bros.          5.55
#  Super Smash Bros. for Wii U and 3DS          5.02
#                    Street Fighter IV          4.19
#              Street Fighter II Turbo          4.10
#                Tekken Tag Tournament          4.05
#                             Tekken 5          3.87
#                       WWF SmackDown!          3.58
#                             Tekken 4          3.44
#                         WWF War Zone          3.36
#                               Tekken          3.24
#                      Killer Instinct          3.20
#     WWF SmackDown! 2: Know Your Role          3.20
#               Dragon Ball Z: Budokai          3.09
#             Mike Tyson's Punch-Out!!          3.02

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=top15, x='Global_Sales', y='Name', palette='viridis')
plt.xlabel('Global Sales (in millions)')
plt.ylabel('Game Name')
plt.title('Top 20 Highest Global sales in Fighting Games')

plt.show()

# %%
sports = df[df['Genre'] == 'Adventure']
sales = sports.sort_values('Global_Sales',ascending=False)
result = sales[['Name','Global_Sales']]
top15 = result.head(20)
print(top15.to_string(index=False))
# Out:
#                                     Name  Global_Sales
#       Super Mario Land 2: 6 Golden Coins         11.18
#                         Assassin's Creed          5.55
#                         Assassin's Creed          4.83
#          Zelda II: The Adventure of Link          4.38
#               Rugrats: Search For Reptar          3.34
#                               L.A. Noire          3.23
#        Club Penguin: Elite Penguin Force          3.16
#                               Heavy Rain          3.12
#                                     Myst          2.81
#                               L.A. Noire          2.72
#                Riven: The Sequel to Myst          2.43
# Frogger's Adventures: Temple of the Frog          2.39
#            Onimusha 2: Samurai's Destiny          2.25
# The Legend of Zelda: Link's Awakening DX          2.22
#           Scooby Doo and the Cyber Chase          1.94
#                      Star Fox Adventures          1.87
#   The Legend of Zelda: Oracle of Seasons          1.86
#                        Beyond: Two Souls          1.79
#              Metroid II: Return of Samus          1.76
#  Star Wars Episode I: The Phantom Menace          1.74

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=top15, x='Global_Sales', y='Name', palette='viridis')
plt.xlabel('Global Sales (in millions)')
plt.ylabel('Game Name')
plt.title('Top 20 Highest Global sales in Adventure games ')

plt.show()

# %%
sports = df[df['Genre'] == 'Strategy']
sales = sports.sort_values('Global_Sales',ascending=False)
result = sales[['Name','Global_Sales']]
top15 = result.head(20)
print(top15.to_string(index=False))
# Out:
#                               Name  Global_Sales
#                    Pokemon Stadium          5.45
#                       Warzone 2100          5.01
#     StarCraft II: Wings of Liberty          4.83
#     Warcraft II: Tides of Darkness          4.21
#          Pokémon Trading Card Game          3.70
#       Command & Conquer: Red Alert          2.85
#                  Pokémon Stadium 2          2.73
#                          Halo Wars          2.63
#                     Theme Hospital          2.40
#            Warcraft: Orcs & Humans          2.08
#                     Sim Theme Park          2.08
# Yu-Gi-Oh! The Eternal Duelist Soul          2.07
#         Sid Meier's Civilization V          1.69
#   StarCraft II: Heart of the Swarm          1.67
#                             Pikmin          1.63
#            Yu-Gi-Oh! Duel Monsters          1.61
#    Command & Conquer: Tiberian Sun          1.55
#              LEGO Battles: Ninjago          1.55
#    Warcraft III: The Frozen Throne          1.54
#                          Anno 2070          1.45

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=top15, x='Global_Sales', y='Name', palette='viridis')
plt.xlabel('Global Sales (in millions)')
plt.ylabel('Game Name')
plt.title('Top 20 Highest Global sales in Strategy Games')

plt.show()
